# %%
import os 
import pandas as pd

from pandas_profiling import ProfileReport
from pandas_profiling.utils.cache import cache_file
from collections import Counter
import seaborn as sn
import random
import matplotlib.pyplot as plt

import numpy as np

# %%
box_file_dir = os.path.join(os.getcwd(), "..", "..", "Box")
file_path_csv = os.path.join(box_file_dir, "covid_pts_enc_level_labs_dx_2021-02-02_deid.csv")

# %%
df = pd.read_csv(file_path_csv, index_col=False)

# %%
df.head()
# Out:
#            admit_dt_tm      discharge_dt_tm        facility  \
# 0  2020-08-25 20:51:00  2020-09-01 14:30:00     Shoal Creek
# 1  2020-03-24 00:07:00  2020-03-26 18:30:00  Medical Center
# 2  2020-03-25 13:25:00  2020-03-30 03:48:00  Medical Center
# 3  2020-03-25 13:36:00  2020-03-27 13:15:00  Medical Center
# 4  2020-03-25 13:43:00  2020-03-27 12:44:00  Medical Center
#
#          encounter_type_display  age_at_admit  gender zip_cust_table  \
# 0  IP Private/Semi Private room            49    Male        Unknown
# 1                        IP ICU            44    Male          78130
# 2  IP Private/Semi Private room            80  Female          78758
# 3  IP Private/Semi Private room            56    Male          78746
# 4  IP Private/Semi Private room            46  Female          78757
#
#         ethnicity_display               race_display            race_eth_comb  \
# 0      Hispanic or Latino                      White           White Hispanic
# ...

# %%
all_df_list = []

# %%
def gen_plots(use_df, allocation_type):
    thresholds = np.linspace(0,1,11)
    
    for t in thresholds:
        temp = use_df[use_df['threshold'].isin( [t, 1.1])]
        sn_plot = sn.factorplot(x='threshold', y='death_percent', 
                                hue='race', hue_order = race_hue_labels, data=temp , kind='bar')
        plt.title(allocation_type+' Scheme compared to Actual Death Rate')
        plt.show()

        temp = use_df[use_df['threshold'].isin( [t, 1.0])]
        sn_plot = sn.factorplot(x='threshold', y='death_percent', 
                                hue='race', hue_order = race_hue_labels, data=temp , kind='bar')
        plt.title(allocation_type+' Scheme compared to No Scarcity of Ventilators')
        plt.show()

# %% [markdown]
# ### Sickest First

# %%
try_df_sickest= pd.read_csv('sickest_data_results.csv', index_col=False)

# %%
race_hue_labels = try_df_sickest['race'].unique()

# %%
gen_plots(try_df_sickest, 'Sickest First')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ### Lottery

# %%
lot_df= pd.read_csv('lottery_data_results.csv', index_col=False)
gen_plots(lot_df, 'Lottery')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ### New York

# %%
lot_df= pd.read_csv('ny_data_results.csv', index_col=False)
gen_plots(lot_df, 'New York')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ### Maryland

# %%
lot_df= pd.read_csv('mar_data_results.csv', index_col=False)
gen_plots(lot_df, 'Maryland')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ### Max Life Years

# %%
lot_df= pd.read_csv('max_lives_data_results.csv', index_col=False)
gen_plots(lot_df, 'Max Life Years')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...

# %% [markdown]
# ### Youngest

# %%
lot_df= pd.read_csv('youngest_data_results.csv', index_col=False)
gen_plots(lot_df, 'Youngest')
# Out:
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/joel/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ...
